# %%
#Imports
import numpy as np
import pandas as pd
import tensorflow.keras.backend as k
from sklearn.preprocessing import MinMaxScaler,  RobustScaler
from tensorflow import keras
from tensorflow.keras import Sequential, layers, optimizers, losses, regularizers
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber

# %%
import numpy as np
import pandas as pd

# Read a specific sheet
df = pd.read_excel(r"C:\Users\William\OneDrive\Documents\Data Cleaning\LARUAN.xlsx",
                   sheet_name='04-VAL04H-PM-1 MIRANDA-PSAN_Pre')

df.head(20)
# Out:
#    Unnamed: 0                            Unnamed: 1           Unnamed: 2  \
# 0         NaN                                   NaN                  NaN
# 1         NaN                                   NaN                  NaN
# 2         NaN                                   NaN                  NaN
# 3         NaN                                   NaN                  NaN
# 4         NaN                                   NaN                  NaN
# 5         PMP  04-VAL04H-PM-1 MIRANDA-PSAN_Pressure             DATETIME
# 6         NaN                                   NaN  2022-01-01 00:00:00
# 7         NaN                                   NaN  2022-01-01 00:15:00
# 8         NaN                                   NaN  2022-01-01 00:30:00
# 9         NaN                                   NaN  2022-01-01 00:45:00
# 10        NaN                                   NaN  2022-01-01 01:00:00
# 11        NaN                                   NaN  2022-01-01 01:15:00
# 12        NaN                                   NaN  2022-01-01 01:30:00
# 13        NaN                                   NaN  2022-01-01 01:45:00
# 14        NaN                                   NaN  2022-01-01 02:00:00
# 15        NaN                                   NaN  2022-01-01 02:15:00
# 16        NaN                                   NaN  2022-01-01 02:30:00
# 17        NaN                                   NaN  2022-01-01 02:45:00
# 18        NaN                                   NaN  2022-01-01 03:00:00
# 19        NaN                                   NaN  2022-01-01 03:15:00
#
#                                     Unnamed: 3
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          PSI
# 6   [-11057] Not Enough Values For Calculation
# 7   [-11057] Not Enough Values For Calculation
# 8   [-11057] Not Enough Values For Calculation
# 9   [-11057] Not Enough Values For Calculation
# 10  [-11057] Not Enough Values For Calculation
# 11  [-11057] Not Enough Values For Calculation
# 12  [-11057] Not Enough Values For Calculation
# 13  [-11057] Not Enough Values For Calculation
# 14  [-11057] Not Enough Values For Calculation
# 15  [-11057] Not Enough Values For Calculation
# 16  [-11057] Not Enough Values For Calculation
# 17  [-11057] Not Enough Values For Calculation
# 18  [-11057] Not Enough Values For Calculation
# 19  [-11057] Not Enough Values For Calculation

# %%
# Don't use this unless you're gonna change your prv dataset.
# to clean

df.drop(['Unnamed: 1', 'Unnamed: 0'], axis=1, inplace=True)
df.to_csv('semicleaned3.csv', index=False)
df.head(100)
# Out:
#              Unnamed: 2                                  Unnamed: 3
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
# ..                  ...                                         ...
# 95  2022-01-01 22:15:00  [-11057] Not Enough Values For Calculation
# 96  2022-01-01 22:30:00  [-11057] Not Enough Values For Calculation
# 97  2022-01-01 22:45:00  [-11057] Not Enough Values For Calculation
# 98  2022-01-01 23:00:00  [-11057] Not Enough Values For Calculation
# 99  2022-01-01 23:15:00  [-11057] Not Enough Values For Calculation
#
# [100 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
#Cleaning changing Not enough values to NaN
df3 = pd.read_csv("semicleaned3.csv", skiprows=6)
df3.columns = ['DATETIME', 'PSI']
df3.replace('[-11057] Not Enough Values For Calculation', np.nan, inplace=True)
#changing data types

df3['PSI'] = pd.to_numeric(df3['PSI'], errors='coerce')
df3['DATETIME'] = pd.to_datetime(df3['DATETIME'], errors='coerce')
df3.dtypes
df3
# Out:
#                   DATETIME   PSI
# 0      2022-01-01 00:00:00   NaN
# 1      2022-01-01 00:15:00   NaN
# 2      2022-01-01 00:30:00   NaN
# 3      2022-01-01 00:45:00   NaN
# 4      2022-01-01 01:00:00   NaN
# ...                    ...   ...
# 101659 2024-11-24 22:45:00  7.81
# 101660 2024-11-24 23:00:00  9.23
# 101661 2024-11-24 23:15:00  9.94
# 101662 2024-11-24 23:30:00  8.52
# 101663 2024-11-24 23:45:00  9.23
#
# [101664 rows x 2 columns]

# %%
df_new = df3.copy()  # Creates a separate copy
df_new.index = df_new['DATETIME']
df_new.drop('DATETIME', axis=1, inplace=True)

df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00   NaN
# 2022-01-01 00:15:00   NaN
# 2022-01-01 00:30:00   NaN
# 2022-01-01 00:45:00   NaN
# 2022-01-01 01:00:00   NaN
# ...                   ...
# 2024-11-24 22:45:00  7.81
# 2024-11-24 23:00:00  9.23
# 2024-11-24 23:15:00  9.94
# 2024-11-24 23:30:00  8.52
# 2024-11-24 23:45:00  9.23
#
# [101664 rows x 1 columns]

# %%
df_new.loc[df_new['PSI'] > 30, 'PSI'] = np.nan
df_new['PSI'] = df_new['PSI'].interpolate(method='time')
df_new['PSI'] = df_new['PSI'].rolling(window=5, center=True).median()

# %%
df_new.fillna(0, inplace=True)

df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00  0.00
# 2022-01-01 00:15:00  0.00
# 2022-01-01 00:30:00  0.00
# 2022-01-01 00:45:00  0.00
# 2022-01-01 01:00:00  0.00
# ...                   ...
# 2024-11-24 22:45:00  8.52
# 2024-11-24 23:00:00  8.52
# 2024-11-24 23:15:00  9.23
# 2024-11-24 23:30:00  0.00
# 2024-11-24 23:45:00  0.00
#
# [101664 rows x 1 columns]

# %%
#visualizing my dataframe
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))

# Plot using numerical indices on the x-axis
plt.plot(df_new.index, df_new['PSI'], label='PSI')
# Formatting

# %%
df_new['PSI']
# Out:
# DATETIME
# 2022-01-01 00:00:00    0.00
# 2022-01-01 00:15:00    0.00
# 2022-01-01 00:30:00    0.00
# 2022-01-01 00:45:00    0.00
# 2022-01-01 01:00:00    0.00
#                        ...
# 2024-11-24 22:45:00    8.52
# 2024-11-24 23:00:00    8.52
# 2024-11-24 23:15:00    9.23
# 2024-11-24 23:30:00    0.00
# 2024-11-24 23:45:00    0.00
# Name: PSI, Length: 101664, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
len(df_new)
# Out:
# 101664

# %%
train = df_new.iloc[:98784]
test = df_new.iloc[98784:]
train
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00  0.00
# 2022-01-01 00:15:00  0.00
# 2022-01-01 00:30:00  0.00
# 2022-01-01 00:45:00  0.00
# 2022-01-01 01:00:00  0.00
# ...                   ...
# 2024-10-25 22:45:00  9.23
# 2024-10-25 23:00:00  9.23
# 2024-10-25 23:15:00  9.23
# 2024-10-25 23:30:00  9.94
# 2024-10-25 23:45:00  9.94
#
# [98784 rows x 1 columns]

# %%
len(train)
# Out:
# 98784

# %%
len(test)
# Out:
# 2880

# %%
test
# Out:
#                       PSI
# DATETIME
# 2024-10-26 00:00:00  9.94
# 2024-10-26 00:15:00  9.94
# 2024-10-26 00:30:00  9.23
# 2024-10-26 00:45:00  9.23
# 2024-10-26 01:00:00  9.94
# ...                   ...
# 2024-11-24 22:45:00  8.52
# 2024-11-24 23:00:00  8.52
# 2024-11-24 23:15:00  9.23
# 2024-11-24 23:30:00  0.00
# 2024-11-24 23:45:00  0.00
#
# [2880 rows x 1 columns]

# %%
scaler.fit(df_new)
# Out:
# MinMaxScaler()

# %%
scaled_data = scaler.transform(df_new)

# %%
# Function to create sequences while preserving the time series order
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])  # Predicting 'DATA (psi)'
    return np.array(X), np.array(y)

SEQ_LENGTH = 30  # Capture longer-term patterns
X, y = create_sequences(scaled_data, SEQ_LENGTH)

# Reshape for LSTM input (samples, time steps, features)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Train-Test Split (80% training, 20% testing)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]


# Print shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (81307, 30, 1)
# X_test shape: (20327, 30, 1)
# y_train shape: (81307, 1)
# y_test shape: (20327, 1)

# %%
#building model
model = Sequential([
    LSTM(96, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)  # Final output
])

# Compile model with Huber loss and Adam optimizer
model.compile(
    optimizer=Adam(learning_rate=0.005),
    loss=Huber(delta=1),
    metrics=['mae']
)

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Reduce LR if validation loss stops improving
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)

# Model checkpoint to save the best model
model_checkpoint = ModelCheckpoint(
    filepath="best_lstm_modelv8.keras",
    monitor="val_loss",
    save_best_only=True,
    mode="min",
    verbose=1
)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr, model_checkpoint],
    verbose=1
)
# Out:
# c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0053 - mae: 0.0509
# Epoch 1: val_loss improved from inf to 0.00024, saving model to best_lstm_modelv8.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 75s 28ms/step - loss: 0.0053 - mae: 0.0509 - val_loss: 2.4138e-04 - val_mae: 0.0153 - learning_rate: 0.0050
# Epoch 2/30
# 2538/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1113e-04 - mae: 0.0209
# Epoch 2: val_loss improved from 0.00024 to 0.00023, saving model to best_lstm_modelv8.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 47s 19ms/step - loss: 5.1113e-04 - mae: 0.0209 - val_loss: 2.2996e-04 - val_mae: 0.0143 - learning_rate: 0.0050
# Epoch 3/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1828e-04 - mae: 0.0206
# Epoch 3: val_loss did not improve from 0.00023
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 83s 19ms/step - loss: 5.1827e-04 - mae: 0.0206 - val_loss: 3.1030e-04 - val_mae: 0.0193 - learning_rate: 0.0050
# Epoch 4/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.2648e-04 - mae: 0.0203
# Epoch 4: val_loss improved from 0.00023 to 0.00020, saving model to best_lstm_modelv8.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 48s 19ms/step - loss: 5.2647e-04 - mae: 0.0203 - val_loss: 2.0016e-04 - val_mae: 0.0120 - learning_rate: 0.0050
# Epoch 5/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7387e-04 - mae: 0.0193
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 5: val_loss improved from 0.00020 to 0.00020, saving model to best_lstm_modelv8.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 48s 19ms/step - loss: 4.7387e-04 - mae: 0.0193 - val_loss: 1.9799e-04 - val_mae: 0.0124 - learning_rate: 0.0050
# Epoch 6/30
# 2538/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3499e-04 - mae: 0.0176
# Epoch 6: val_loss did not improve from 0.00020
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 49s 19ms/step - loss: 4.3497e-04 - mae: 0.0176 - val_loss: 2.1146e-04 - val_mae: 0.0140 - learning_rate: 0.0025
# Epoch 7/30
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.2764e-04 - mae: 0.0176
# Epoch 7: val_loss improved from 0.00020 to 0.00018, saving model to best_lstm_modelv8.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 20ms/step - loss: 4.2764e-04 - mae: 0.0176 - val_loss: 1.8076e-04 - val_mae: 0.0115 - learning_rate: 0.0025
# Epoch 8/30
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3530e-04 - mae: 0.0176
# Epoch 8: val_loss did not improve from 0.00018
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 53s 21ms/step - loss: 4.3529e-04 - mae: 0.0176 - val_loss: 2.0393e-04 - val_mae: 0.0123 - learning_rate: 0.0025
# Epoch 9/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1578e-04 - mae: 0.0173
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 9: val_loss did not improve from 0.00018
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 52s 20ms/step - loss: 4.1578e-04 - mae: 0.0173 - val_loss: 2.1049e-04 - val_mae: 0.0144 - learning_rate: 0.0025
# Epoch 10/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1147e-04 - mae: 0.0167
# Epoch 10: val_loss did not improve from 0.00018
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 51s 20ms/step - loss: 4.1147e-04 - mae: 0.0167 - val_loss: 2.0489e-04 - val_mae: 0.0136 - learning_rate: 0.0012
# Epoch 11/30
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1973e-04 - mae: 0.0169
# Epoch 11: val_loss did not improve from 0.00018
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 52s 21ms/step - loss: 4.1972e-04 - mae: 0.0169 - val_loss: 3.8006e-04 - val_mae: 0.0225 - learning_rate: 0.0012
# Epoch 12/30
# 1107/2541 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - loss: 4.0849e-04 - mae: 0.0166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 34
#      25 model_checkpoint = ModelCheckpoint(
#      26     filepath="best_lstm_modelv8.keras",
#      27     monitor="val_loss",
#    (...)     30     verbose=1
#      31 )
#      33 # Train the model
# ---> 34 history = model.fit(
#      35     X_train, y_train,
#      36     epochs=30,
#      37     batch_size=32,
#      38     validation_data=(X_test, y_test),
#      39     callbacks=[early_stopping, reduce_lr, model_checkpoint],
#      40     verbose=1
#      41 )
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#checking the prediction
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model("best_lstm_modelv8.keras")

y_pred = best_model.predict(X_test)

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_actual = scaler.inverse_transform(y_pred.reshape(-1, 1))

import matplotlib.pyplot as plt
import numpy as np

# Create time indices for plotting
time_index = np.arange(len(y_test_actual))

plt.figure(figsize=(14, 7))
plt.plot(time_index, y_test_actual, label="Actual Data", color="blue", linewidth=2)
plt.plot(time_index, y_pred_actual, label="Predicted Data", color="red", linewidth=2, alpha=0.6)

plt.title("LSTM Model Forecasting")
plt.xlabel("Time Steps")
plt.ylabel("DATA (psi)")
plt.legend()
plt.show()
# Out:
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# SMAPE function
def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# MAPE function
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))

def mape2(y_true, y_pred):
    y_true, y_pred = pd.Series(y_true), pd.Series(y_pred)
    return (np.abs((y_true - y_pred) / y_true)).mean() * 100

# Calculate SMAPE
smape_value = smape(y_test_actual, y_pred_actual)
print(f"SMAPE: {smape_value:.2f}%")

accuracy = 100 - smape_value
print(f"Model Accuracy: {accuracy:.2f}%")

# Calculate MAPE
mape_value = mape(y_test_actual, y_pred_actual)
print(f"MAPE: {mape_value:.4f}%")

# Calculate MAE
mae = mean_absolute_error(y_test_actual, y_pred_actual)
print(f'MAE: {mae:.4f}')

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual))
print(f'RMSE: {rmse:.4f}')
# Out:
# SMAPE: 4.08%
# Model Accuracy: 95.92%
# MAPE: inf%
# MAE: 0.3659
# RMSE: 0.6075
# C:\Users\William\AppData\Local\Temp\ipykernel_15040\3278674004.py:10: RuntimeWarning: divide by zero encountered in divide
#   return 100 * np.mean(np.abs((y_true - y_pred) / y_true))
