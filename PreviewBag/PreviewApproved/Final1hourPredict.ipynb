# %%
#Imports
import numpy as np
import pandas as pd
import tensorflow.keras.backend as k
from sklearn.preprocessing import MinMaxScaler,  RobustScaler
from tensorflow import keras
from tensorflow.keras import Sequential, layers, optimizers, losses, regularizers
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber

# %%
import numpy as np
import pandas as pd

# Read a specific sheet
df = pd.read_excel(r"C:\Users\William\OneDrive\Documents\Data Cleaning\LARUAN.xlsx",
                   sheet_name='04-VAL04H-PM-1 MIRANDA-PSAN_Pre')

df.head(20)
# Out:
#    Unnamed: 0                            Unnamed: 1           Unnamed: 2  \
# 0         NaN                                   NaN                  NaN
# 1         NaN                                   NaN                  NaN
# 2         NaN                                   NaN                  NaN
# 3         NaN                                   NaN                  NaN
# 4         NaN                                   NaN                  NaN
# 5         PMP  04-VAL04H-PM-1 MIRANDA-PSAN_Pressure             DATETIME
# 6         NaN                                   NaN  2022-01-01 00:00:00
# 7         NaN                                   NaN  2022-01-01 00:15:00
# 8         NaN                                   NaN  2022-01-01 00:30:00
# 9         NaN                                   NaN  2022-01-01 00:45:00
# 10        NaN                                   NaN  2022-01-01 01:00:00
# 11        NaN                                   NaN  2022-01-01 01:15:00
# 12        NaN                                   NaN  2022-01-01 01:30:00
# 13        NaN                                   NaN  2022-01-01 01:45:00
# 14        NaN                                   NaN  2022-01-01 02:00:00
# 15        NaN                                   NaN  2022-01-01 02:15:00
# 16        NaN                                   NaN  2022-01-01 02:30:00
# 17        NaN                                   NaN  2022-01-01 02:45:00
# 18        NaN                                   NaN  2022-01-01 03:00:00
# 19        NaN                                   NaN  2022-01-01 03:15:00
#
#                                     Unnamed: 3
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          PSI
# 6   [-11057] Not Enough Values For Calculation
# 7   [-11057] Not Enough Values For Calculation
# 8   [-11057] Not Enough Values For Calculation
# 9   [-11057] Not Enough Values For Calculation
# 10  [-11057] Not Enough Values For Calculation
# 11  [-11057] Not Enough Values For Calculation
# 12  [-11057] Not Enough Values For Calculation
# 13  [-11057] Not Enough Values For Calculation
# 14  [-11057] Not Enough Values For Calculation
# 15  [-11057] Not Enough Values For Calculation
# 16  [-11057] Not Enough Values For Calculation
# 17  [-11057] Not Enough Values For Calculation
# 18  [-11057] Not Enough Values For Calculation
# 19  [-11057] Not Enough Values For Calculation

# %%
# Don't use this unless you're gonna change your prv dataset.
# to clean

df.drop(['Unnamed: 1', 'Unnamed: 0'], axis=1, inplace=True)
df.to_csv('semicleaned3.csv', index=False)
df.head(100)
# Out:
#              Unnamed: 2                                  Unnamed: 3
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
# ..                  ...                                         ...
# 95  2022-01-01 22:15:00  [-11057] Not Enough Values For Calculation
# 96  2022-01-01 22:30:00  [-11057] Not Enough Values For Calculation
# 97  2022-01-01 22:45:00  [-11057] Not Enough Values For Calculation
# 98  2022-01-01 23:00:00  [-11057] Not Enough Values For Calculation
# 99  2022-01-01 23:15:00  [-11057] Not Enough Values For Calculation
#
# [100 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
#Cleaning changing Not enough values to NaN
df3 = pd.read_csv("semicleaned3.csv", skiprows=6)
df3.columns = ['DATETIME', 'PSI']
df3.replace('[-11057] Not Enough Values For Calculation', np.nan, inplace=True)
#changing data types

df3['PSI'] = pd.to_numeric(df3['PSI'], errors='coerce')
df3['DATETIME'] = pd.to_datetime(df3['DATETIME'], errors='coerce')
df3.dtypes
df3
# Out:
#                   DATETIME   PSI
# 0      2022-01-01 00:00:00   NaN
# 1      2022-01-01 00:15:00   NaN
# 2      2022-01-01 00:30:00   NaN
# 3      2022-01-01 00:45:00   NaN
# 4      2022-01-01 01:00:00   NaN
# ...                    ...   ...
# 101659 2024-11-24 22:45:00  7.81
# 101660 2024-11-24 23:00:00  9.23
# 101661 2024-11-24 23:15:00  9.94
# 101662 2024-11-24 23:30:00  8.52
# 101663 2024-11-24 23:45:00  9.23
#
# [101664 rows x 2 columns]

# %%
df_new = df3.copy()  # Creates a separate copy
df_new.index = df_new['DATETIME']
df_new.drop('DATETIME', axis=1, inplace=True)

df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00   NaN
# 2022-01-01 00:15:00   NaN
# 2022-01-01 00:30:00   NaN
# 2022-01-01 00:45:00   NaN
# 2022-01-01 01:00:00   NaN
# ...                   ...
# 2024-11-24 22:45:00  7.81
# 2024-11-24 23:00:00  9.23
# 2024-11-24 23:15:00  9.94
# 2024-11-24 23:30:00  8.52
# 2024-11-24 23:45:00  9.23
#
# [101664 rows x 1 columns]

# %%
df_new.loc[df_new['PSI'] > 30, 'PSI'] = np.nan
df_new['PSI'] = df_new['PSI'].interpolate(method='time')
df_new['PSI'] = df_new['PSI'].rolling(window=5, center=True).median()

# %%
df_new.fillna(0, inplace=True)

df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00  0.00
# 2022-01-01 00:15:00  0.00
# 2022-01-01 00:30:00  0.00
# 2022-01-01 00:45:00  0.00
# 2022-01-01 01:00:00  0.00
# ...                   ...
# 2024-11-24 22:45:00  8.52
# 2024-11-24 23:00:00  8.52
# 2024-11-24 23:15:00  9.23
# 2024-11-24 23:30:00  0.00
# 2024-11-24 23:45:00  0.00
#
# [101664 rows x 1 columns]

# %%
#visualizing my dataframe
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))

# Plot using numerical indices on the x-axis
plt.plot(df_new.index, df_new['PSI'], label='PSI')
# Formatting

# %%
df_new['PSI']
# Out:
# DATETIME
# 2022-01-01 00:00:00    0.00
# 2022-01-01 00:15:00    0.00
# 2022-01-01 00:30:00    0.00
# 2022-01-01 00:45:00    0.00
# 2022-01-01 01:00:00    0.00
#                        ...
# 2024-11-24 22:45:00    8.52
# 2024-11-24 23:00:00    8.52
# 2024-11-24 23:15:00    9.23
# 2024-11-24 23:30:00    0.00
# 2024-11-24 23:45:00    0.00
# Name: PSI, Length: 101664, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
len(df_new)
# Out:
# 101664

# %%
train = df_new.iloc[:98784]
test = df_new.iloc[98784:]
train
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00  0.00
# 2022-01-01 00:15:00  0.00
# 2022-01-01 00:30:00  0.00
# 2022-01-01 00:45:00  0.00
# 2022-01-01 01:00:00  0.00
# ...                   ...
# 2024-10-25 22:45:00  9.23
# 2024-10-25 23:00:00  9.23
# 2024-10-25 23:15:00  9.23
# 2024-10-25 23:30:00  9.94
# 2024-10-25 23:45:00  9.94
#
# [98784 rows x 1 columns]

# %%
len(train)
# Out:
# 98784

# %%
len(test)
# Out:
# 2880

# %%
test
# Out:
#                       PSI
# DATETIME
# 2024-10-26 00:00:00  9.94
# 2024-10-26 00:15:00  9.94
# 2024-10-26 00:30:00  9.23
# 2024-10-26 00:45:00  9.23
# 2024-10-26 01:00:00  9.94
# ...                   ...
# 2024-11-24 22:45:00  8.52
# 2024-11-24 23:00:00  8.52
# 2024-11-24 23:15:00  9.23
# 2024-11-24 23:30:00  0.00
# 2024-11-24 23:45:00  0.00
#
# [2880 rows x 1 columns]

# %%
scaler.fit(df_new)
# Out:
# MinMaxScaler()

# %%
scaled_data = scaler.transform(df_new)

# %%
# Function to create sequences while preserving the time series order
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])  # Predicting 'DATA (psi)'
    return np.array(X), np.array(y)

SEQ_LENGTH = 60  # Capture longer-term patterns
X, y = create_sequences(scaled_data, SEQ_LENGTH)

# Reshape for LSTM input (samples, time steps, features)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Train-Test Split (80% training, 20% testing)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]


# Print shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (81283, 60, 1)
# X_test shape: (20321, 60, 1)
# y_train shape: (81283, 1)
# y_test shape: (20321, 1)

# %%
#building model
model = Sequential([
    LSTM(96, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1)  # Final output
])

# Compile model with Huber loss and Adam optimizer
model.compile(
    optimizer=Adam(learning_rate=0.005),
    loss=Huber(delta=1),
    metrics=['mae']
)

# Reduce LR if validation loss stops improving
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)

# Model checkpoint to save the best model
model_checkpoint = ModelCheckpoint(
    filepath="PredictOneHour.keras",
    monitor="val_loss",
    save_best_only=True,
    mode="min",
    verbose=1
)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[ reduce_lr, model_checkpoint],
    verbose=1
)
# Out:
# Epoch 1/20
# c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0026 - mae: 0.0411
# Epoch 1: val_loss improved from inf to 0.00020, saving model to PredictOneHour.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 88s 34ms/step - loss: 0.0026 - mae: 0.0410 - val_loss: 1.9809e-04 - val_mae: 0.0133 - learning_rate: 0.0050
# Epoch 2/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.9446e-04 - mae: 0.0207
# Epoch 2: val_loss did not improve from 0.00020
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 86s 34ms/step - loss: 4.9448e-04 - mae: 0.0207 - val_loss: 2.6597e-04 - val_mae: 0.0173 - learning_rate: 0.0050
# Epoch 3/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.9031e-04 - mae: 0.0199
# Epoch 3: val_loss did not improve from 0.00020
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 33ms/step - loss: 4.9031e-04 - mae: 0.0199 - val_loss: 1.9969e-04 - val_mae: 0.0132 - learning_rate: 0.0050
# Epoch 4/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.6870e-04 - mae: 0.0194
# Epoch 4: val_loss improved from 0.00020 to 0.00019, saving model to PredictOneHour.keras
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 33ms/step - loss: 4.6870e-04 - mae: 0.0194 - val_loss: 1.9285e-04 - val_mae: 0.0129 - learning_rate: 0.0050
# Epoch 5/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0087 - mae: 0.0760
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 5: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 85s 34ms/step - loss: 0.0087 - mae: 0.0760 - val_loss: 0.0020 - val_mae: 0.0542 - learning_rate: 0.0050
# Epoch 6/20
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0025 - mae: 0.0512
# Epoch 6: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - loss: 0.0025 - mae: 0.0512 - val_loss: 0.0017 - val_mae: 0.0507 - learning_rate: 0.0025
# Epoch 7/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0016 - mae: 0.0384
# Epoch 7: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 85s 33ms/step - loss: 0.0016 - mae: 0.0384 - val_loss: 7.8989e-04 - val_mae: 0.0329 - learning_rate: 0.0025
# Epoch 8/20
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mae: 0.0344
# Epoch 8: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 85s 33ms/step - loss: 0.0013 - mae: 0.0344 - val_loss: 5.7133e-04 - val_mae: 0.0260 - learning_rate: 0.0025
# Epoch 9/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - mae: 0.0307
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 9: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - loss: 0.0010 - mae: 0.0307 - val_loss: 5.2725e-04 - val_mae: 0.0249 - learning_rate: 0.0025
# Epoch 10/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.5341e-04 - mae: 0.0273
# Epoch 10: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 85s 34ms/step - loss: 8.5338e-04 - mae: 0.0273 - val_loss: 5.3341e-04 - val_mae: 0.0251 - learning_rate: 0.0012
# Epoch 11/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.2497e-04 - mae: 0.0253
# Epoch 11: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 86s 34ms/step - loss: 7.2498e-04 - mae: 0.0253 - val_loss: 4.2122e-04 - val_mae: 0.0213 - learning_rate: 0.0012
# Epoch 12/20
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7025e-04 - mae: 0.0239
# Epoch 12: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 33ms/step - loss: 6.7025e-04 - mae: 0.0239 - val_loss: 4.0501e-04 - val_mae: 0.0207 - learning_rate: 0.0012
# Epoch 13/20
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.3797e-04 - mae: 0.0231
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
#
# Epoch 13: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 86s 34ms/step - loss: 6.3797e-04 - mae: 0.0231 - val_loss: 3.8985e-04 - val_mae: 0.0204 - learning_rate: 0.0012
# Epoch 14/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.1178e-04 - mae: 0.0219
# Epoch 14: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 87s 34ms/step - loss: 6.1176e-04 - mae: 0.0219 - val_loss: 3.4391e-04 - val_mae: 0.0172 - learning_rate: 6.2500e-04
# Epoch 15/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.7476e-04 - mae: 0.0215
# Epoch 15: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - loss: 5.7476e-04 - mae: 0.0215 - val_loss: 3.8007e-04 - val_mae: 0.0194 - learning_rate: 6.2500e-04
# Epoch 16/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.7883e-04 - mae: 0.0214
# Epoch 16: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 86s 34ms/step - loss: 5.7882e-04 - mae: 0.0214 - val_loss: 3.2660e-04 - val_mae: 0.0175 - learning_rate: 6.2500e-04
# Epoch 17/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.6253e-04 - mae: 0.0211
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
#
# Epoch 17: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 33ms/step - loss: 5.6253e-04 - mae: 0.0211 - val_loss: 3.1841e-04 - val_mae: 0.0166 - learning_rate: 6.2500e-04
# Epoch 18/20
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.2926e-04 - mae: 0.0204
# Epoch 18: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - loss: 5.2926e-04 - mae: 0.0204 - val_loss: 3.3014e-04 - val_mae: 0.0173 - learning_rate: 3.1250e-04
# Epoch 19/20
# 2540/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.5934e-04 - mae: 0.0205
# Epoch 19: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 87s 34ms/step - loss: 5.5932e-04 - mae: 0.0205 - val_loss: 3.6457e-04 - val_mae: 0.0187 - learning_rate: 3.1250e-04
# Epoch 20/20
# 2539/2541 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.2996e-04 - mae: 0.0202
# Epoch 20: val_loss did not improve from 0.00019
# 2541/2541 ━━━━━━━━━━━━━━━━━━━━ 84s 33ms/step - loss: 5.2996e-04 - mae: 0.0202 - val_loss: 3.2082e-04 - val_mae: 0.0163 - learning_rate: 3.1250e-04

# %%
# Plot 1: Training Data and Test Predictions
plt.figure(figsize=(18, 8))

# Plot training actual (history)
plt.plot(df_new.index[:len(y_train)], y_train, 
         label="Training Actual", color="blue", linewidth=2)

# Plot test predictions
plt.plot(df_new.index[len(y_train):len(y_train) + len(y_test)], y_test, 
         label="Test Predictions", color="orange", linewidth=2)

plt.title("Training Data and Test Predictions", fontsize=16)
plt.xlabel("Time Steps", fontsize=14)
plt.ylabel("Pressure (PSI)", fontsize=14)
plt.legend(fontsize=12, loc='upper left')
plt.axvline(x=df_new.index[len(y_train) - 1], color='black', linestyle=':', alpha=0.5)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Plot 2: Training Data and Actual Test Data
plt.figure(figsize=(18, 8))

# Plot training actual (history)
plt.plot(df_new.index[:len(y_train)], y_train, 
         label="Training Actual", color="blue", linewidth=2)

# Plot test actual (ground truth)
plt.plot(df_new.index[len(y_train):len(y_train) + len(y_test)], y_test,
         label="Test Actual", color="red", linewidth=2)

plt.title("Training Data and Actual Test Data", fontsize=16)
plt.xlabel("Time", fontsize=14)  # Changed from "Time Steps" to "Time" since using datetime index
plt.ylabel("Pressure (PSI)", fontsize=14)
plt.legend(fontsize=12, loc='upper left')

# Add vertical separator between train and test
plt.axvline(x=df_new.index[len(y_train) - 1], 
            color='black', linestyle=':', alpha=0.5)

# Add region labels (positioned at 15% of y-axis height)
y_pos = plt.ylim()[0] + 0.15 * (plt.ylim()[1] - plt.ylim()[0])
plt.text(df_new.index[len(y_train)//2], y_pos, "TRAIN", 
         ha='center', fontsize=12, bbox=dict(facecolor='white', alpha=0.8))
plt.text(df_new.index[len(y_train) + len(y_test)//2], y_pos, "TEST", 
         ha='center', fontsize=12, bbox=dict(facecolor='white', alpha=0.8))

plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)  # Rotate datetime labels for better readability
plt.tight_layout()
plt.show()

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
loss_per_epoch = model.history.history['val_loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# SMAPE function
def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# MAPE function
def mape(y_true, y_pred):
    return 100 * np.mean(np.abs((y_true - y_pred) / y_true))

def mape2(y_true, y_pred):
    y_true, y_pred = pd.Series(y_true), pd.Series(y_pred)
    return (np.abs((y_true - y_pred) / y_true)).mean() * 100

# Generate predictions for the test set
y_pred = model.predict(X_test)

# Calculate SMAPE
smape_value = smape(y_test, y_pred)
print(f"SMAPE: {smape_value:.2f}%")

# Calculate MAPE
mape_value = mape(y_test, y_pred)
print(f"MAPE: {mape_value:.4f}%")

# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print(f'MAE: {mae:.4f}')

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'RMSE: {rmse:.4f}')
# Out:
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step
# SMAPE: 4.14%
# MAPE: 4.2156%
# MAE: 0.0163
# RMSE: 0.0253
